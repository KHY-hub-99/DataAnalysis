# %% [markdown]
# # 1. 서울 열린데이터 광장

# %% [markdown]
# [서울 열린데이터 광장](https://data.seoul.go.kr/)(Seoul Open Data Plaza)은 서울시에서 운영하는 공공데이터 개방 플랫폼입니다. 시민, 연구자, 기업 등이 서울시에서 생성한 다양한 공공데이터를 자유롭게 활용할 수 있도록 제공하고 있습니다. 이를 통해 데이터 기반의 창의적인 아이디어와 혁신을 촉진하며, 시민들의 정보 접근성을 높이고 공공서비스를 개선하는 데 기여하고 있습니다.

# %% [markdown]
# # 2. 서울시 공공자전거 실시간 대여정보

# %% [markdown]
# 1. 인증키를 발급 받습니다.
#
# 2. "서울시 공공자전거 실시간 대여정보" 를 검색합니다.
#
# 6a7458436967757336315578595679

# %%
import requests
import pandas as pd
import folium
import json
import warnings
warnings.filterwarnings('ignore')

# %%
urls = []
start = 1
end = 1000
for i in range(1, 4):
  url = f"http://openapi.seoul.go.kr:8088/6a7458436967757336315578595679/json/bikeList/{start}/{end}/"
  start = (1000 * i) + 1
  end = (1000*i) + 1000
  urls.append(url)

# %%
datas = []
for url in urls:
  req = requests.get(url)
  data = req.json()
  json_data = data.get("rentBikeStatus", {}).get("row", "")
  datas.append(json_data)

# %%
x, y = datas[0][0]["stationLatitude"], datas[0][0]["stationLongitude"]

# %%
def fetch_bike():
  base_url = "http://openapi.seoul.go.kr:8088/6a7458436967757336315578595679/json/bikeList/"
  start = 1
  end = 1000
  step = 1000
  data_frames = []

  while True:
      url = f"{base_url}{start}/{end}/"
      response = requests.get(url)

      if response.status_code != 200:
          print(f"Status Code: {response.status_code}")
          break

      json_data = response.json()

      try:
          rent_bike_status = json_data["rentBikeStatus"]
          result_code = rent_bike_status["RESULT"]["CODE"]
      except KeyError:
          print("JSON 오류")
          break

      if result_code == "INFO-200":
          print("데이터 없음")
          break
      elif result_code == "INFO-000":
          print(f"시작: {start} 끝: {end}.")
          try:
              bike_data = rent_bike_status["row"]
              if bike_data:
                  df = pd.DataFrame(bike_data)
                  data_frames.append(df)
          except KeyError:
              print("데이터를 찾을 수 없음")
      else:
          print(f"result code: {result_code}")
          break

      start += step
      end += step

  if data_frames:
      final_df = pd.concat(data_frames, ignore_index=True)
      return final_df
  else:
      return pd.DataFrame()

# %%
bike_data = fetch_bike()
# Out:
# 시작: 1 끝: 1000.
# 시작: 1001 끝: 2000.
# 시작: 2001 끝: 3000.
# JSON 오류

# %%
bike_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2758 entries, 0 to 2757
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rackTotCnt         2758 non-null   object
#  1   stationName        2758 non-null   object
#  2   parkingBikeTotCnt  2758 non-null   object
#  3   shared             2758 non-null   object
#  4   stationLatitude    2758 non-null   object
#  5   stationLongitude   2758 non-null   object
#  6   stationId          2758 non-null   object
# dtypes: object(7)
# memory usage: 151.0+ KB

# %% [markdown]
# ```
# rackTotCnt  거치대개수
# parkingBikeTotCnt   자전거주차총건수
# shared  거치율
# stationLatitude 위도
# stationLongitude    경도
# stationId   대여소ID
# stationName 대여소이름
# ```

# %%
bike_data[["stationLatitude", "stationLongitude"]] = bike_data[["stationLatitude", "stationLongitude"]].astype(float)
bike_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2758 entries, 0 to 2757
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rackTotCnt         2758 non-null   object
#  1   stationName        2758 non-null   object
#  2   parkingBikeTotCnt  2758 non-null   object
#  3   shared             2758 non-null   object
#  4   stationLatitude    2758 non-null   float64
#  5   stationLongitude   2758 non-null   float64
#  6   stationId          2758 non-null   object
# dtypes: float64(2), object(5)
# memory usage: 151.0+ KB

# %%
bike_map = folium.Map(location=[bike_data.stationLatitude.mean(), bike_data.stationLongitude.mean()], zoom_start=14)

for index, data in bike_data.iterrows():
  popup_str = f"{data.stationName} 자전거 주차 총 건수 : {data.parkingBikeTotCnt}"
  popup = folium.Popup(popup_str, max_width=600)
  folium.Marker(location=[data.stationLatitude, data.stationLongitude], popup=popup).add_to(bike_map)

bike_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a34a54cdbdc765cc0a3ee4e7a4c005f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a34a54cdbdc765cc0a3ee4e7a4c005f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a34a54cdbdc765cc0a3ee4e7a4c005f = L.map(
#                 &quot;map_0a34a54cdbdc765cc0a3ee4e7a4c005f&quot;,
#                 {
#                     center: [37.54799064123278, 126.99142330457578],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_67e08532285349a1aa47f0d28588c09c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_67e08532285349a1aa47f0d28588c09c.addTo(map_0a34a54cdbdc765cc0a3ee4e7a4c005f);
#
#
#             var marker_866faf46875db63bc7de9d14c3055f4a = L.marker(
#                 [37.5556488, 126.91062927],
#                 {
# }
#             ).addTo(map_0a34a54cdbdc765cc0a3ee4e7a4c005f);
#
#
#         var popup_29e279b9203d7bd6e79bb2d985e8a999 = L.popup({
#   &quot;maxWidth&quot;: 600,
# });
#
#
#
#                 var html_4660d4a7ef818afe6c36716c9f4ffab0 = $(`&lt;div id=&quot;html_4660d4a7ef818afe6c36716c9f4ffab0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;102. 망원역 1번출구 앞 자전거 주차 총 건수 : 1&lt;/div&gt;`)[0];
#                 popup_29e279b9203d7bd6e79bb2d985e8a999.setContent(html_4660d4a7ef818afe6c36716c9f4ffab0);
#
#
#
#         marker_866faf46875db63bc7de9d14c3055f4a.bindPopup(popup_29e279b9203d7bd6e79bb2d985e8a999)
#         ;
#
#
#
#
#             var marker_e06421870aae4e4fd45f828989cf2eb5 = L.marker(
#                 [37.55495071, 126.91083527],
#                 {
# }
#             ).addTo(map_0a34a54cdbdc765cc0a3ee4e7a4c005f);
#
#
#         var popup_f932276bdbf325e52edfb7b2594243d3 = L.popup({
#   &quot;maxWidth&quot;: 600,
# });
#
#
#
#                 var html_a659f448638363d0cd3443e601527a16 = $(`&lt;div id=&quot;html_a659f448638363d0cd3443e601527a16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;103. 망원역 2번출구 앞 자전거 주차 총 건수 : 18&lt;/div&gt;`)[0];
#                 popup_f932276bdbf325e52edfb7b2594243d3.setContent(html_a659f448638363d0cd3443e601527a16);
#
#
#
#         marker_e06421870aae4e4fd45f828989cf2eb5.bindPopup(popup_f932276bdbf325e52edfb7b2594243d3)
#         ;
#
#
#
#
#             var marker_992ab0316235f7e14f9a604c6f23d031 = L.marker(
#                 [37.55073929, 126.91508484],
#                 {
# }
#             ).addTo(map_0a34a54cdbdc765cc0a3ee4e7a4c005f);
#
#
#         var popup_1cc9eb05fac99f33bd7bba2f2984328a = L.popup({
#   &quot;maxWidth&quot;: 600,
# });
#
#
#
#                 var html_fa5f15f153dd9647c51ade54d056a866 = $(`&lt;div id=&quot;html_fa5f15f153dd9647c51ade54d056a866&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;104. 합정역 1번출구 앞 자전거 주차 총 건수 : 4&lt;/div&gt;`)[0];
#                 popup_1cc9eb05fac99f33bd7bba2f2984328a.setContent(html_fa5f15f153dd9647c51ade54d056a866);
#
#
#
#         marker_992ab0316235f7e14f9a604c6f23d031.bindPopup(popup_1cc9eb05fac99f33bd7bba2f2984328a)
#         ;
#
#
#
#
#             var marker_396e7efec2d711fa0a00db0d9a61e484 = L.marker(
#                 [37.55000687, 126.91482544],
#                 {
# }
#             ).addTo(map_0a34a54cdbdc765cc0a3ee4e7a4c005f);
#
#
#         var popup_03786f11331102c4651f5778c2ce6244 = L.popup({
#   &quot;maxWidth&quot;: 600,
# });
#
#
#
#                 var html_57baea529fd91efe9e698f8d77568acb = $(`&lt;div id=&quot;html_57baea529fd91efe9e698f8d77568acb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;105. 합정역 5번출구 앞 자전거 주차 총 건수 : 0&lt;/div&gt;`)[0];
#                 popup_03786f11331102c4651f5778c2ce6244.setContent(html_57baea529fd91efe9e698f8d77568acb);
#
#
#
#         marker_396e7efec2d711fa0a00db0d9a61e484.bindPopup(popup_03786f11331102c4651f5778c2ce6244)
#         ;
#
#
#
#
#             var marker_42fdf69477c5517b2c838e0cde2c1391 = L.marker(
#                 [37.54864502, 126.91282654],
#                 {
# }
#             ).addTo(map_0a34a54cdbdc765cc0a3ee4e7a4c005f);
#
#
#         var popup_5c183b19a632d457c8e8b645fa0ee5fc = L.popup({
#   &quot;maxWidth&quot;: 600,
# });
#
#
#
#                 var html_a97ce846910cbaa672df0ce58a7df5bc = $(`&lt;div id=&quot;html_a97ce846910cbaa672df0ce58a7df5bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;106. 합정역 7번출구 앞 자전거 주차 총 건수 : 3&lt;/div&gt;`)[0];
#                 popup_5c183b19a632d457c8e8b645fa0ee5fc.setContent(html_a97ce84
